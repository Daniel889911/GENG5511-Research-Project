# %%
from annotator import Annotator
from label_categories_fleiss import Label_Metrics
import graphs as gr
import warnings
import pandas as pd

annotator1 = Annotator('annotator1', "annotations-TBikaun.json")
annotator2 = Annotator('annotator2', "annotations-ziyu.zhao.json")
annotator3 = Annotator('annotator3', "annotations-danielsantosa.json")
annotator4 = Annotator('annotator4', "annotations-mhodki.json")
annotator5 = Annotator('annotator5', "annotations-mstewartuwa.json")
annotator6 = Annotator('annotator6', "annotations-caitlinwoods.json")
annotator7 = Annotator('annotator7', "annotations-Tim.json")
label = Label_Metrics(annotator1, annotator2, annotator3)
overall_table = label.get_accumulated_table_labels()

# %%
label_agreements = label.calculate_fleiss_kappas(overall_table)

# %%
agreement_summary = label.create_agreement_summary(label_agreements)
agreement_summary
# Out:
#    low agreement medium low agreement  \
# 0            NaN                  NaN
# 1            NaN                  NaN
# 2            NaN                  NaN
# 3            NaN                  NaN
# 4            NaN                  NaN
# 5            NaN                  NaN
# 6            NaN                  NaN
# 7            NaN                  NaN
# 8            NaN                  NaN
# 9            NaN                  NaN
# 10           NaN                  NaN
# 11           NaN                  NaN
# 12           NaN                  NaN
# 13           NaN                  NaN
# 14           NaN                  NaN
# 15           NaN                  NaN
# 16           NaN                  NaN
# 17           NaN                  NaN
# 18           NaN                  NaN
# 19           NaN                  NaN
# 20           NaN                  NaN
# 21           NaN                  NaN
# 22           NaN                  NaN
# 23           NaN                  NaN
# 24           NaN                  NaN
# 25           NaN                  NaN
#
#                                      medium agreement  \
# 0                Attribute Observation/Observed_state
# 1                     Typo Observation/Observed_state
# 2                               Attribute Observation
# 3                                               Agent
# 4                               Location Abbreviation
# 5              Observation/Observed_state Observation
# 6                     Observation/Observed_state Typo
# 7             Observation/Observed_state Abbreviation
# 8                                         Observation
# 9                             Observation/Qualitative
# 10                                          Item Typo
# 11                                          Typo Item
# 12                                             Unsure
# 13                                  Consumable Unsure
# 14                                       Abbreviation
# 15                                      Activity Typo
# 16                                          Specifier
# 17                Observation Observation/Qualitative
# 18                             Item Typo Abbreviation
# 19                                  Item Abbreviation
# 20  Observation/Qualitative Observation/Observed_s...
# 21                                          Attribute
# 22                               Consumable Specifier
# 23                                               Typo
# 24                                           No Label
# 25                                        Item Unsure
#
#                      medium high agreement high agreement
# 0   Observation Observation/Observed_state       Activity
# 1                                     Item       Location
# 2                              Cardinality            NaN
# 3                                     Time            NaN
# 4                               Consumable            NaN
# 5               Observation/Observed_state            NaN
# 6                                      NaN            NaN
# 7                                      NaN            NaN
# 8                                      NaN            NaN
# 9                                      NaN            NaN
# 10                                     NaN            NaN
# 11                                     NaN            NaN
# 12                                     NaN            NaN
# 13                                     NaN            NaN
# 14                                     NaN            NaN
# 15                                     NaN            NaN
# 16                                     NaN            NaN
# 17                                     NaN            NaN
# 18                                     NaN            NaN
# 19                                     NaN            NaN
# 20                                     NaN            NaN
# 21                                     NaN            NaN
# 22                                     NaN            NaN
# 23                                     NaN            NaN
# 24                                     NaN            NaN
# 25                                     NaN            NaN
