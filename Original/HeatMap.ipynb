# %%
from annotator import Annotator
from label import Label_Metrics
from ngram import Ngram_Metrics
import graphs as gr

tyler = Annotator('tyler', "annotations-TBikaun.json")
daniel = Annotator('daniel', "annotations-danielsantosa.json")
caitlin = Annotator('caitlin', "annotations-caitlinwoods.json")
ziyu = Annotator('ziyu', "annotations-ziyu.zhao.json")
michael = Annotator('michael', "annotations-mstewartuwa.json")
tim = Annotator('tim', "annotations-Tim.json")
melinda = Annotator('melinda', "annotations-mhodki.json")
ngram = Ngram_Metrics(daniel, ziyu, tyler)
corpus_metrics = ngram.get_corpus_metrics()
label_ngram_metrics = ngram.get_label_ngram_metrics(corpus_metrics)
print(label_ngram_metrics)
# Out:
# [['Item', 1, 0.8333333333333333], ['Item', 4, 0.8333333333333333], ['Item', 2, 1.0], ['Observation/Observed_state', 1, 0.5], ['Observation/Observed_state', 2, 0.8333333333333333], ['Observation Observation/Observed_state Typo', 4, 0.8333333333333333], ['Observation Observation/Observed_state Typo', 2, 0.8333333333333333], ['Observation Observation/Observed_state Typo', 3, 0.8333333333333333], ['Activity', 1, 0.5], ['Activity', 4, 0.5], ['Location', 1, 1.0], ['Location', 4, 1.0], ['Location', 2, 0.8333333333333333], ['Item Item Typo', 1, 0.8333333333333333], ['Item Item Typo', 4, 0.8333333333333333], ['Item Item Typo', 2, 0.8333333333333333], ['Item Item Typo', 3, 0.8333333333333333], ['Observation Observation/Observed_state', 2, 0.8333333333333333], ['Observation Observation/Observed_state', 3, 0.8333333333333333], ['Attribute Specifier Observation/Observed_state', 1, 1.0], ['Attribute Specifier Observation/Observed_state', 4, 1.0], ['Attribute Specifier Observation/Observed_state', 2, 1.0], ['Attribute Specifier Observation/Observed_state', 3, 1.0], ['Time Item', 2, 0.8333333333333333], ['Time Item', 3, 0.8333333333333333], ['Specifier Observation/Observed_state', 1, 0.8333333333333333], ['Specifier Observation/Observed_state', 4, 0.8333333333333333], ['Specifier Observation/Observed_state', 2, 0.8333333333333333], ['Specifier Observation/Observed_state', 3, 0.8333333333333333], ['Consumable', 1, 0.5], ['Consumable', 4, 0.5], ['Consumable', 2, 0.5], ['Consumable', 3, 0.5], ['Item Consumable', 1, 0.8333333333333333], ['Item Consumable', 4, 0.8333333333333333], ['Item Consumable', 2, 0.8333333333333333], ['Item Consumable', 3, 0.8333333333333333], ['Observation Attribute', 1, 0.8333333333333333], ['Observation Attribute', 4, 0.8333333333333333], ['Observation Attribute', 2, 0.8333333333333333], ['Observation Attribute', 3, 0.8333333333333333], ['Abbreviation Observation/Observed_state Observation/Observed_state Abbreviation', 1, 1.0], ['Abbreviation Observation/Observed_state Observation/Observed_state Abbreviation', 4, 1.0], ['Abbreviation Observation/Observed_state Observation/Observed_state Abbreviation', 2, 1.0], ['Abbreviation Observation/Observed_state Observation/Observed_state Abbreviation', 3, 1.0], ['Observation/Qualitative', 1, 0.5], ['Observation/Qualitative', 4, 0.5], ['Location Item', 1, 0.8333333333333333], ['Location Item', 4, 0.8333333333333333], ['Location Item', 2, 0.8333333333333333], ['Location Item', 3, 0.8333333333333333], ['Typo Item Abbreviation', 1, 0.8333333333333333], ['Typo Item Abbreviation', 4, 0.8333333333333333], ['Typo Item Abbreviation', 2, 0.8333333333333333], ['Typo Item Abbreviation', 3, 0.8333333333333333], ['Observation Observation/Qualitative', 1, 0.8333333333333333], ['Observation Observation/Qualitative', 4, 0.8333333333333333], ['Observation Observation/Qualitative', 2, 0.8333333333333333], ['Observation Observation/Qualitative', 3, 0.8333333333333333], ['Specifier Observation/Qualitative', 1, 0.8333333333333333], ['Specifier Observation/Qualitative', 4, 0.8333333333333333], ['Specifier Observation/Qualitative', 2, 0.8333333333333333], ['Specifier Observation/Qualitative', 3, 0.8333333333333333], ['Attribute Observation/Observed_state', 1, 0.8333333333333333], ['Attribute Observation/Observed_state', 4, 0.8333333333333333], ['Attribute Observation/Observed_state', 2, 0.8333333333333333], ['Attribute Observation/Observed_state', 3, 0.8333333333333333], ['Agent Cardinality', 1, 0.8333333333333333], ['Agent Cardinality', 4, 0.8333333333333333], ['Agent Cardinality', 2, 0.8333333333333333], ['Agent Cardinality', 3, 0.8333333333333333], ['Attribute Typo Observation Observation/Observed_state', 1, 0.8333333333333333], ['Attribute Typo Observation Observation/Observed_state', 4, 0.8333333333333333], ['Attribute Typo Observation Observation/Observed_state', 2, 0.8333333333333333], ['Attribute Typo Observation Observation/Observed_state', 3, 0.8333333333333333], ['Item Specifier', 1, 0.8333333 ...

# %%
gr.create_heatmap(label_ngram_metrics)
