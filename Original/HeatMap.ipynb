# %%
from annotator import Annotator
from label import Label_Metrics
from ngram import Ngram_Metrics
import graphs as gr

tyler = Annotator('tyler', "annotations-TBikaun.json")
daniel = Annotator('daniel', "annotations-danielsantosa.json")
caitlin = Annotator('caitlin', "annotations-caitlinwoods.json")
ziyu = Annotator('ziyu', "annotations-ziyu.zhao.json")
michael = Annotator('michael', "annotations-mstewartuwa.json")
tim = Annotator('tim', "annotations-Tim.json")
melinda = Annotator('melinda', "annotations-mhodki.json")
ngram = Ngram_Metrics(ziyu, tyler, caitlin, tim)
corpus_metrics = ngram.get_corpus_metrics()
label_ngram_metrics = ngram.get_label_ngram_metrics(corpus_metrics)
print(label_ngram_metrics)
# Out:
# [['Item', 1, 1.0], ['Item', 4, 1.0], ['Item', 2, 1.0], ['Item', 3, 1.0], ['Observation/Observed_state Typo', 1, 1.0], ['Observation/Observed_state Typo', 4, 1.0], ['Observation/Observed_state Typo', 2, 1.0], ['Observation/Observed_state Typo', 3, 1.0], ['Activity', 1, 1.0], ['Activity', 4, 1.0], ['Activity', 2, 1.0], ['Activity', 3, 1.0], ['Observation/Observed_state', 1, 1.0], ['Observation/Observed_state', 4, 1.0], ['Observation/Observed_state', 2, 1.0], ['Observation/Observed_state', 3, 1.0], ['Location', 1, 1.0], ['Location', 4, 1.0], ['Location', 2, 1.0], ['Location', 3, 1.0], ['Item Typo', 1, 1.0], ['Item Typo', 4, 1.0], ['Item Typo', 2, 1.0], ['Item Typo', 3, 1.0]]

# %%
gr.create_heatmap(label_ngram_metrics)
