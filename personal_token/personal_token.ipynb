# %%
from annotator import Annotator
from personal_token import Label_Metrics
import graphs as gr
import pandas as pd

annotator1 = Annotator('annotator1', "annotations-TBikaun.json")
annotator2 = Annotator('annotator2', "annotations-ziyu.zhao.json")
annotator3 = Annotator('annotator3', "annotations-danielsantosa.json")
annotator4 = Annotator('annotator4', "annotations-mhodki.json")
annotator5 = Annotator('annotator5', "annotations-mstewartuwa.json")
annotator6 = Annotator('annotator6', "annotations-caitlinwoods.json")
annotator7 = Annotator('annotator7', "annotations-Tim.json")
label = Label_Metrics(annotator1, annotator2, annotator3)
overall_table = label.get_accumulated_table_labels()

# %%
annotators_agreements = label.get_annotator_label_agreements(overall_table)
summary_dfs = label.create_agreement_summary(annotators_agreements)
summary_dfs['annotator1'].head(40)
# Out:
#       lowest agreement medium-low agreement medium agreement  \
# 0       won " t raise.                  NaN         cylinder
# 1                hose.                  NaN        levelling
# 2               hoses.                  NaN   levelling jack
# 3                    3                  NaN   manufacturer30
# 4           drive tyre                  NaN              cyl
# 5                 flat                  NaN              pin
# 6            breathers                  NaN             line
# 7            vibration                  NaN            under
# 8                  u/s                  NaN        hydrauilc
# 9   leaking dust badly                  NaN        hydraulic
# 10  will not stay shut                  NaN           button
# 11             fluoros                  NaN          exhaust
# 12      need attention                  NaN              NaN
# 13        on the blink                  NaN              NaN
# 14              coming                  NaN              NaN
# 15        coming loose                  NaN              NaN
# 16               loose                  NaN              NaN
# 17                rhs.                  NaN              NaN
# 18                   5                  NaN              NaN
# 19                head                  NaN              NaN
# 20         out of wack                  NaN              NaN
# 21              slides                  NaN              NaN
# 22                wack                  NaN              NaN
# 23      break out dies                  NaN              NaN
# 24             /modify                  NaN              NaN
# 25                cups                  NaN              NaN
# 26           pos. cups                  NaN              NaN
# 27          /refurbish                  NaN              NaN
# 28        deck spanner                  NaN              NaN
# 29           feed line                  NaN              NaN
# 30                leak                  NaN              NaN
# 31               block                  NaN              NaN
# 32         valve block                  NaN              NaN
# 33          under rear                  NaN              NaN
# 34             lh side                  NaN              NaN
# 35       potable water                  NaN              NaN
# 36                stop                  NaN              NaN
# 37         tool wrench                  NaN              NaN
# 38             lh rear                  NaN              NaN
# 39               hyd.s                  NaN              NaN
#
#    medium-high agreement      high agreement
# 0                   jack                   "
# 1                   pump                mast
# 2             pump drive              raise.
# 3                    cab                   t
# 4                   deck                 won
# 5                     to               blown
# 6                  guide          blown hose
# 7                   pipe                hose
# 8                     lh               index
# 9                  valve      index cylinder
# 10                 under                  on
# 11                  rear             replace
# 12               control                  NA
# 13                 water          oil cooler
# 14                   NaN                slap
# 15                   NaN         slap wrench
# 16                   NaN              wrench
# 17                   NaN            carousel
# 18                   NaN           on top of
# 19                   NaN  replace blown hose
# 20                   NaN         blown hose.
# 21                   NaN         blown hoses
# 22                   NaN               hoses
# 23                   NaN        blown hoses.
# 24                   NaN      blown hyd hose
# 25                   NaN            hyd hose
# 26                   NaN            inverter
# 27                   NaN        tripping out
# 28                   NaN          change out
# 29                   NaN               drive
# 30                   NaN                 pos
# 31                   NaN                tyre
# 32                   NaN               front
# 33                   NaN       drive gearbox
# 34                   NaN             gearbox
# 35                   NaN                gear
# 36                   NaN                 sun
# 37                   NaN            sun gear
# 38                   NaN                 vlc
# 39                   NaN         fuel filter

# %%
high_agreement_list = summary_dfs['annotator1']['lowest agreement'].tolist()
print(high_agreement_list)
# Out:
# ['won " t raise.', 'hose.', 'hoses.', '3', 'drive tyre', 'flat', 'breathers', 'vibration', 'u/s', 'leaking dust badly', 'will not stay shut', 'fluoros', 'need attention', 'on the blink', 'coming', 'coming loose', 'loose', 'rhs.', '5', 'head', 'out of wack', 'slides', 'wack', 'break out dies', '/modify', 'cups', 'pos. cups', '/refurbish', 'deck spanner', 'feed line', 'leak', 'block', 'valve block', 'under rear', 'lh side', 'potable water', 'stop', 'tool wrench', 'lh rear', 'hyd.s', '9', 'valve bypass', 'hydraulic button', 'hydraulic control', "wo n't switch of", 'fault', 'guide block', 'temp probes', 'connector', 'expansion', 'expansion connector', 'expansion joint', 'joint', 'input', 'output', 'locking', 'locking cylinder', 'oil tank', 'tank', '@', 'water [ pump', 'walkway', 'off', 'off the', 'crane', 'lifting', 'lifting crane', 'rotation', 'rotation pump', 'hyd.', 'hyd. pipe', 'from', 'from rear', 'in l/h/s', 'jumper hose', 'r/h', 'die', 'die holders', 'holders', 'flood light', 'repaired', 'box', 'drive box', 'middle', 'upper', 'upper & middle', 'level', 'lines', 'oil lines', '&air', 'discharge', 'discharge gauges', 'gauges', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]
