# %%
from annotator import Annotator
from personal_token import Label_Metrics
import graphs as gr
import pandas as pd

tyler = Annotator('tyler', "annotations-TBikaun.json")
daniel = Annotator('daniel', "annotations-danielsantosa.json")
caitlin = Annotator('caitlin', "annotations-caitlinwoods.json")
ziyu = Annotator('ziyu', "annotations-ziyu.zhao.json")
michael = Annotator('michael', "annotations-mstewartuwa.json")
tim = Annotator('tim', "annotations-Tim.json")
melinda = Annotator('melinda', "annotations-mhodki.json")
label = Label_Metrics(ziyu, tyler, daniel)
overall_table = label.get_accumulated_table_labels()

# %%
annotators_agreements = label.get_annotator_label_agreements(overall_table)
summary_dfs = label.create_agreement_summary(annotators_agreements)
pd.set_option('display.max_rows', None)
summary_dfs['daniel']
# Out:
#      lowest agreement medium-low agreement medium agreement  \
# 0                   "                  NaN              NaN
# 1              raise.                  NaN              NaN
# 2                   t                  NaN              NaN
# 3                 won                  NaN              NaN
# 4            cylinder                  NaN              NaN
# 5               index                  NaN              NaN
# 6      index cylinder                  NaN              NaN
# 7                  NA                  NaN              NaN
# 8                  on                  NaN              NaN
# 9                slap                  NaN              NaN
# 10        slap wrench                  NaN              NaN
# 11             wrench                  NaN              NaN
# 12           carousel                  NaN              NaN
# 13              drive                  NaN              NaN
# 14                pos                  NaN              NaN
# 15               tyre                  NaN              NaN
# 16               gear                  NaN              NaN
# 17                sun                  NaN              NaN
# 18           sun gear                  NaN              NaN
# 19                vlc                  NaN              NaN
# 20              check                  NaN              NaN
# 21                 in                  NaN              NaN
# 22            machine                  NaN              NaN
# 23              badly                  NaN              NaN
# 24               dust                  NaN              NaN
# 25            leaking                  NaN              NaN
# 26                not                  NaN              NaN
# 27               shut                  NaN              NaN
# 28               stay                  NaN              NaN
# 29               will                  NaN              NaN
# 30              shut.                  NaN              NaN
# 31               wont                  NaN              NaN
# 32         wont shut.                  NaN              NaN
# 33              blink                  NaN              NaN
# 34                 on                  NaN              NaN
# 35                the                  NaN              NaN
# 36                  #                  NaN              NaN
# 37                  1                  NaN              NaN
# 38                  #                  NaN              NaN
# 39                  &                  NaN              NaN
# 40                 of                  NaN              NaN
# 41                out                  NaN              NaN
# 42                  &                  NaN              NaN
# 43                  &                  NaN              NaN
# 44               lube                  NaN              NaN
# 45       lube station                  NaN              NaN
# 46                oil                  NaN              NaN
# 47            station                  NaN              NaN
# 48                  &                  NaN              NaN
# 49            ITEM_ID                  NaN              NaN
# 50                  /                  NaN              NaN
# 51                 NA                  NaN              NaN
# 52                  /                  NaN              NaN
# 53              break                  NaN              NaN
# 54                out                  NaN              NaN
# 55               pos.                  NaN              NaN
# 56               dril                  NaN              NaN
# 57          dril rods                  NaN              NaN
# 58               rods                  NaN              NaN
# 59     manufacturer30                  NaN              NaN
# 60                 to                  NaN              NaN
# 61                  m                  NaN              NaN
# 62            missing                  NaN              NaN
# 63               pins                  NaN              NaN
# 64              split                  NaN              NaN
# 65         split pins                  NaN              NaN
# 66               jack                  NaN              NaN
# 67          levelling                  NaN              NaN
# 68     levelling jack                  NaN              NaN
# 69               deck                  NaN              NaN
# 70            spanner                  NaN              NaN
# 71               feed                  NaN              NaN
# 72                oil                  NaN              NaN
# 73              turbo                  NaN              NaN
# 74                 NA                  NaN              NaN
# 75                oil                  NaN              NaN
# 76                oil                  NaN              NaN
# 77                oil                  NaN              NaN
# 78                  .                  NaN              NaN
# 79                oil                  NaN              NaN
# 80                oil                  NaN              NaN
# 81                oil                  NaN              NaN
# 82                  -                  NaN              NaN
# 83                oil                  NaN              NaN
# 84                oil                  NaN              NaN
# 85                oil                  NaN              NaN
# 86             broken                  NaN              NaN
# 87            ITEM_ID                  NaN              NaN
# 88             broken                  NaN              NaN
# 89               lock                  NaN              NaN
# 90           lock pin                  NaN              NaN
# 91                pin                  NaN              NaN
# 92                  ?                  NaN              NaN
# 93                 lh                  NaN              NaN
# 94               side                  NaN              NaN
# 95            ITEM_ID                  NaN              NaN
# 96             broken                  NaN              NaN
# 97             chains                  NaN              NaN
# 98               down                  NaN              NaN
# 99               pull                  NaN              NaN
# 100  pull down chains                  NaN              NaN
# 101            broken                  NaN              NaN
# 102            broken                  NaN              NaN
# 103            broken                  NaN              NaN
# 104              tool                  NaN              NaN
# 105            wrench                  NaN              NaN
# 106            broken                  NaN              NaN
# 107                lh                  NaN              NaN
# 108              rear                  NaN              NaN
# 109            broken                  NaN              NaN
# 110                on                  NaN              NaN
# 111         wont turn                  NaN              NaN
# 112      wont turn on                  NaN              NaN
# 113           spanner                  NaN              NaN
# 114               oil                  NaN              NaN
# 115             spool                  NaN              NaN
# 116     spool stacker                  NaN              NaN
# 117           stacker                  NaN              NaN
# 118             valve                  NaN              NaN
# 119               not                  NaN              NaN
# 120       not working                  NaN              NaN
# 121           working                  NaN              NaN
# 122           control                  NaN              NaN
# 123               n't                  NaN              NaN
# 124                of                  NaN              NaN
# 125            switch                  NaN              NaN
# 126                wo                  NaN              NaN
# 127           control                  NaN              NaN
# 128               not                  NaN              NaN
# 129    not staying on                  NaN              NaN
# 130                on                  NaN              NaN
# 131           staying                  NaN              NaN
# 132           ITEM_ID                  NaN              NaN
# 133                 &                  NaN              NaN
# 134             guide                  NaN              NaN
# 135           ITEM_ID                  NaN              NaN
# 136            probes                  NaN              NaN
# 137              temp                  NaN              NaN
# 138                NA                  NaN              NaN
# 139               and                  NaN              NaN
# 140               and                  NaN              NaN
# 141                 f                  NaN              NaN
# 142           ITEM_ID                  NaN              NaN
# 143           ITEM_ID                  NaN              NaN
# 144             turbo                  NaN              NaN
# 145                 &                  NaN              NaN
# 146               oil                  NaN              NaN
# 147             seper                  NaN              NaN
# 148               and                  NaN              NaN
# 149                as                  NaN              NaN
# 150        inspection                  NaN              NaN
# 151          required                  NaN              NaN
# 152                 [                  NaN              NaN
# 153               the                  NaN              NaN
# 154             small                  NaN              NaN
# 155                of                  NaN              NaN
# 156         injection                  NaN              NaN
# 157             water                  NaN              NaN
# 158   water injection                  NaN              NaN
# 159                 /                  NaN              NaN
# 160         injection                  NaN              NaN
# 161             water                  NaN              NaN
# 162   water injection                  NaN              NaN
# 163               aux                  NaN              NaN
# 164              fuel                  NaN              NaN
# 165      fuel system.                  NaN              NaN
# 166           system.                  NaN              NaN
# 167               cyl                  NaN              NaN
# 168               end                  NaN              NaN
# 169              feed                  NaN              NaN
# 170          feed cyl                  NaN              NaN
# 171                in                  NaN              NaN
# 172             l/h/s                  NaN              NaN
# 173               top                  NaN              NaN
# 174           top end                  NaN              NaN
# 175                NA                  NaN              NaN
# 176             guide                  NaN              NaN
# 177   guide regulator                  NaN              NaN
# 178         regulator                  NaN              NaN
# 179                 &                  NaN              NaN
# 180              hose                  NaN              NaN
# 181            jumper                  NaN              NaN
# 182           ITEM_ID                  NaN              NaN
# 183                NA                  NaN              NaN
# 184             break                  NaN              NaN
# 185  break out wrench                  NaN              NaN
# 186               out                  NaN              NaN
# 187            wrench                  NaN              NaN
# 188             break                  NaN              NaN
# 189  break out wrench                  NaN              NaN
# 190               out                  NaN              NaN
# 191            wrench                  NaN              NaN
# 192                NA                  NaN              NaN
# 193          breakout                  NaN              NaN
# 194   breakout wrench                  NaN              NaN
# 195            wrench                  NaN              NaN
# 196          breakout                  NaN              NaN
# 197  breakout wrench.                  NaN              NaN
# 198           wrench.                  NaN              NaN
# 199               dip                  NaN              NaN
# 200         dip stick                  NaN              NaN
# 201             stick                  NaN              NaN
# 202             flood                  NaN              NaN
# 203             light                  NaN              NaN
# 204            supply                  NaN              NaN
# 205           circuit                  NaN              NaN
# 206              feed                  NaN              NaN
# 207      feed circuit                  NaN              NaN
# 208               oil                  NaN              NaN
# 209              slap                  NaN              NaN
# 210       slap wrench                  NaN              NaN
# 211            wrench                  NaN              NaN
# 212             motor                  NaN              NaN
# 213              step                  NaN              NaN
# 214        step motor                  NaN              NaN
# 215               sub                  NaN              NaN
# 216                 ?                  NaN              NaN
# 217               oil                  NaN              NaN
# 218                 &                  NaN              NaN
# 219               oil                  NaN              NaN
# 220                 &                  NaN              NaN
# 221              jobs                  NaN              NaN
# 222              misc                  NaN              NaN
# 223               oil                  NaN              NaN
# 224               oil                  NaN              NaN
# 225                 d                  NaN              NaN
# 226               not                  NaN              NaN
# 227          pressure                  NaN              NaN
# 228            faulty                  NaN              NaN
# 229               oil                  NaN              NaN
# 230               NaN                  NaN              NaN
# 231               NaN                  NaN              NaN
# 232               NaN                  NaN              NaN
# 233               NaN                  NaN              NaN
# 234               NaN                  NaN              NaN
# 235               NaN                  NaN              NaN
# 236               NaN                  NaN              NaN
# 237               NaN                  NaN              NaN
# 238               NaN                  NaN              NaN
# 239               NaN                  NaN              NaN
# 240               NaN                  NaN              NaN
# 241               NaN                  NaN              NaN
# 242               NaN                  NaN              NaN
# 243               NaN                  NaN              NaN
# 244               NaN                  NaN              NaN
# 245               NaN                  NaN              NaN
# 246               NaN                  NaN              NaN
# 247               NaN                  NaN              NaN
# 248               NaN                  NaN              NaN
# 249               NaN                  NaN              NaN
# 250               NaN                  NaN              NaN
# 251               NaN                  NaN              NaN
# 252               NaN                  NaN              NaN
# 253               NaN                  NaN              NaN
# 254               NaN                  NaN              NaN
# 255               NaN                  NaN              NaN
# 256               NaN                  NaN              NaN
# 257               NaN                  NaN              NaN
# 258               NaN                  NaN              NaN
# 259               NaN                  NaN              NaN
# 260               NaN                  NaN              NaN
# 261               NaN                  NaN              NaN
# 262               NaN                  NaN              NaN
# 542               NaN                  NaN              NaN
# 543               NaN                  NaN              NaN
# 544               NaN                  NaN              NaN
# 545               NaN                  NaN              NaN
# 546               NaN                  NaN              NaN
# 547               NaN                  NaN              NaN
# 548               NaN                  NaN              NaN
# 549               NaN                  NaN              NaN
# 550               NaN                  NaN              NaN
# 551               NaN                  NaN              NaN
# 552               NaN                  NaN              NaN
# 553               NaN                  NaN              NaN
# 554               NaN                  NaN              NaN
# 555               NaN                  NaN              NaN
# 556               NaN                  NaN              NaN
# 557               NaN                  NaN              NaN
# 558               NaN                  NaN              NaN
# 559               NaN                  NaN              NaN
# 560               NaN                  NaN              NaN
# 561               NaN                  NaN              NaN
# 562               NaN                  NaN              NaN
# 563               NaN                  NaN              NaN
# 564               NaN                  NaN              NaN
# 565               NaN                  NaN              NaN
# 566               NaN                  NaN              NaN
# 567               NaN                  NaN              NaN
# 568               NaN                  NaN              NaN
# 569               NaN                  NaN              NaN
# 570               NaN                  NaN              NaN
# 571               NaN                  NaN              NaN
# 572               NaN                  NaN              NaN
# 573               NaN                  NaN              NaN
# 574               NaN                  NaN              NaN
# 575               NaN                  NaN              NaN
# 576               NaN                  NaN              NaN
# 577               NaN                  NaN              NaN
# 578               NaN                  NaN              NaN
# 579               NaN                  NaN              NaN
# 580               NaN                  NaN              NaN
# 581               NaN                  NaN              NaN
# 582               NaN                  NaN              NaN
# 583               NaN                  NaN              NaN
# 584               NaN                  NaN              NaN
# 585               NaN                  NaN              NaN
# 586               NaN                  NaN              NaN
# 587               NaN                  NaN              NaN
#
#     medium-high agreement       high agreement
# 0                     NaN                 mast
# 1                     NaN       won " t raise.
# 2                     NaN                blown
# 3                     NaN           blown hose
# 4                     NaN                 hose
# 5                     NaN                   on
# 6                     NaN              replace
# 7                     NaN                blown
# 8                     NaN           blown hose
# 9                     NaN                 hose
# 10                    NaN                 mast
# 11                    NaN                   on
# 12                    NaN              replace
# 13                    NaN                blown
# 14                    NaN           blown hose
# 15                    NaN                 hose
# 16                    NaN           oil cooler
# 17                    NaN                   on
# 18                    NaN              replace
# 19                    NaN                blown
# 20                    NaN           blown hose
# 21                    NaN                 hose
# 22                    NaN              replace
# 23                    NaN                blown
# 24                    NaN                 hose
# 25                    NaN            on top of
# 26                    NaN              replace
# 27                    NaN   replace blown hose
# 28                    NaN                blown
# 29                    NaN          blown hose.
# 30                    NaN                hose.
# 31                    NaN              replace
# 32                    NaN                blown
# 33                    NaN          blown hoses
# 34                    NaN                hoses
# 35                    NaN              replace
# 36                    NaN                blown
# 37                    NaN         blown hoses.
# 38                    NaN               hoses.
# 39                    NaN              replace
# 40                    NaN                blown
# 41                    NaN       blown hyd hose
# 42                    NaN             hyd hose
# 43                    NaN              replace
# 44                    NaN             inverter
# 45                    NaN         tripping out
# 46                    NaN                    3
# 47                    NaN           change out
# 48                    NaN           drive tyre
# 49                    NaN                 flat
# 50                    NaN           change out
# 51                    NaN                front
# 52                    NaN                 jack
# 53                    NaN            levelling
# 54                    NaN       levelling jack
# 55                    NaN           change out
# 56                    NaN        drive gearbox
# 57                    NaN                front
# 58                    NaN              gearbox
# 59                    NaN                 pump
# 60                    NaN           pump drive
# 61                    NaN           change out
# 62                    NaN                front
# 63                    NaN           change out
# 64                    NaN                front
# 65                    NaN           change out
# 66                    NaN          fuel filter
# 67                    NaN           change out
# 68                    NaN                 fuel
# 69                    NaN    fuel priming pump
# 70                    NaN              priming
# 71                    NaN                 pump
# 72                    NaN            breathers
# 73                    NaN           change out
# 74                    NaN            fuel tank
# 75                    NaN  fuel tank breathers
# 76                    NaN           change out
# 77                    NaN   fuel transfer pump
# 78                    NaN            vibration
# 79                    NaN                  cab
# 80                    NaN             cab door
# 81                    NaN                 door
# 82                    NaN         not shutting
# 83                    NaN                  cab
# 84                    NaN             cab door
# 85                    NaN                 door
# 86                    NaN              opening
# 87                    NaN       cab door seals
# 88                    NaN              replace
# 89                    NaN                  u/s
# 90                    NaN                  cab
# 91                    NaN             cab door
# 92                    NaN                 deck
# 93                    NaN                 door
# 94                    NaN   leaking dust badly
# 95                    NaN                   to
# 96                    NaN                  cab
# 97                    NaN             cab door
# 98                    NaN                 door
# 99                    NaN        not stay shut
# 100                   NaN   will not stay shut
# 101                   NaN                  cab
# 102                   NaN             cab door
# 103                   NaN                 door
# 104                   NaN            wont open
# 105                   NaN                  cab
# 106                   NaN             cab door
# 107                   NaN                 door
# 108                   NaN                  cab
# 109                   NaN          cab fluoros
# 110                   NaN              fluoros
# 111                   NaN       need attention
# 112                   NaN                  cab
# 113                   NaN          cab fluoros
# 114                   NaN              fluoros
# 115                   NaN         on the blink
# 116                   NaN                  cab
# 117                   NaN          cab glasses
# 118                   NaN               coming
# 119                   NaN         coming loose
# 120                   NaN              glasses
# 121                   NaN                loose
# 122                   NaN              replace
# 123                   NaN                 rhs.
# 124                   NaN         track roller
# 125                   NaN                    5
# 126                   NaN                cabin
# 127                   NaN         cabin window
# 128                   NaN              replace
# 129                   NaN               window
# 130                   NaN               adjust
# 131                   NaN                 head
# 132                   NaN          head slides
# 133                   NaN          out of wack
# 134                   NaN              replace
# 135                   NaN               slides
# 136                   NaN                 wack
# 137                   NaN               adjust
# 138                   NaN                guide
# 139                   NaN              replace
# 140                   NaN          rotary head
# 141                   NaN    rotary head guide
# 142                   NaN             relocate
# 143                   NaN              replace
# 144                   NaN        grouser bolts
# 145                   NaN              replace
# 146                   NaN              tighten
# 147                   NaN            refurbish
# 148                   NaN              replace
# 149                   NaN                  rod
# 150                   NaN                   x1
# 151                   NaN            break out
# 152                   NaN       break out dies
# 153                   NaN                 dies
# 154                   NaN               repair
# 155                   NaN              replace
# 156                   NaN              /modify
# 157                   NaN                 cups
# 158                   NaN                 pipe
# 159                   NaN            pipe pos.
# 160                   NaN            pos. cups
# 161                   NaN              replace
# 162                   NaN           /refurbish
# 163                   NaN              replace
# 164                   NaN                   lh
# 165                   NaN                refit
# 166                   NaN                track
# 167                   NaN                chain
# 168                   NaN                refit
# 169                   NaN              machine
# 170                   NaN       manufacturer30
# 171                   NaN                refit
# 172                   NaN          locking pin
# 173                   NaN                 mast
# 174                   NaN                refit
# 175                   NaN              machine
# 176                   NaN                 mast
# 177                   NaN                refit
# 178                   NaN                   to
# 179                   NaN                  cyl
# 180                   NaN           cyl mounts
# 181                   NaN               mounts
# 182                   NaN                   on
# 183                   NaN                refit
# 184                   NaN                  pad
# 185                   NaN                refit
# 186                   NaN                   on
# 187                   NaN                  pad
# 188                   NaN                refit
# 189                   NaN         deck spanner
# 190                   NaN                  pin
# 191                   NaN     pin deck spanner
# 192                   NaN                refit
# 193                   NaN      pipe positioner
# 194                   NaN              replace
# 195                   NaN               switch
# 196                   NaN            feed line
# 197                   NaN                 leak
# 198                   NaN                 line
# 199                   NaN             oil feed
# 200                   NaN                   on
# 201                   NaN               repair
# 202                   NaN                block
# 203                   NaN                 leak
# 204                   NaN                   on
# 205                   NaN               repair
# 206                   NaN                valve
# 207                   NaN          valve block
# 208                   NaN                chest
# 209                   NaN                 leak
# 210                   NaN                   on
# 211                   NaN               repair
# 212                   NaN                valve
# 213                   NaN          valve chest
# 214                   NaN           compressor
# 215                   NaN                 leak
# 216                   NaN               repair
# 217                   NaN                under
# 218                   NaN                 leak
# 219                   NaN           oil cooler
# 220                   NaN               repair
# ...
# 262                   NaN                strap
# 263                   NaN               repair
# 264                   NaN                 stop
# 265                   NaN          tool wrench
# 266                   NaN          wrench stop
# 267                   NaN                 jack
# 268                   NaN              lh rear
# 269                   NaN         lh rear jack
# 270                   NaN                   on
# 271                   NaN               repair
# 272                   NaN                 wire
# 273                   NaN                 mast
# 274                   NaN                   on
# 275                   NaN               repair
# 276                   NaN                wires
# 277                   NaN            bull hose
# 278                   NaN               repair
# 279                   NaN                hyd.s
# 280                   NaN                 deck
# 281                   NaN         deck spanner
# 282                   NaN                 hose
# 283                   NaN            hydrauilc
# 284                   NaN                 leak
# 285                   NaN         spanner hose
# 286                   NaN            hydrauilc
# 287                   NaN                 leak
# 288                   NaN                 mast
# 289                   NaN                   on
# 290                   NaN                    9
# 291                   NaN            hydraulic
# 292                   NaN         valve bypass
# 293                   NaN          access step
# 294                   NaN            hydraulic
# 295                   NaN                 slow
# 296                   NaN               button
# 297                   NaN            hydraulic
# 298                   NaN     hydraulic button
# 299                   NaN               button
# 300                   NaN       control button
# 301                   NaN            hydraulic
# 302                   NaN    hydraulic control
# 303                   NaN     wo n't switch of
# 304                   NaN        control light
# 305                   NaN            hydraulic
# 306                   NaN    hydraulic control
# 307                   NaN                light
# 308                   NaN              control
# 309                   NaN            hydraulic
# 310                   NaN    hydraulic control
# 311                   NaN         tripping out
# 312                   NaN                fault
# 313                   NaN            hydraulic
# 314                   NaN        grouser bolts
# 315                   NaN                 nuts
# 316                   NaN              replace
# 317                   NaN        grouser bolts
# 318                   NaN                   in
# 319                   NaN              replace
# 320                   NaN                spare
# 321                   NaN                track
# 322                   NaN                 dash
# 323                   NaN                guage
# 324                   NaN                   in
# 325                   NaN              replace
# 326                   NaN           hand rails
# 327                   NaN                 mast
# 328                   NaN                   on
# 329                   NaN              replace
# 330                   NaN                block
# 331                   NaN          guide block
# 332                   NaN                 head
# 333                   NaN           head guide
# 334                   NaN              replace
# 335                   NaN                bolts
# 336                   NaN                cover
# 337                   NaN          cover bolts
# 338                   NaN                guide
# 339                   NaN                 head
# 340                   NaN           head guide
# 341                   NaN              replace
# 342                   NaN                guide
# 343                   NaN                 head
# 344                   NaN           head guide
# 345                   NaN              replace
# 346                   NaN          wear strips
# 347                   NaN               guides
# 348                   NaN                 head
# 349                   NaN          head guides
# 350                   NaN              replace
# 351                   NaN                 head
# 352                   NaN         head packing
# 353                   NaN              packing
# 354                   NaN              replace
# 355                   NaN                 head
# 356                   NaN           head slide
# 357                   NaN              replace
# 358                   NaN                slide
# 359                   NaN              exhaust
# 360                   NaN              replace
# 361                   NaN          temp probes
# 362                   NaN              exhaust
# 363                   NaN              replace
# 364                   NaN                 tube
# 365                   NaN            connector
# 366                   NaN            expansion
# 367                   NaN  expansion connector
# 368                   NaN              replace
# 369                   NaN            expansion
# 370                   NaN      expansion joint
# 371                   NaN               gasket
# 372                   NaN                joint
# 373                   NaN              replace
# 374                   NaN            extension
# 375                   NaN               reamer
# 376                   NaN              replace
# 377                   NaN              gearbox
# 378                   NaN                input
# 379                   NaN               output
# 380                   NaN              replace
# 381                   NaN                seals
# 382                   NaN               camera
# 383                   NaN               failed
# 384                   NaN              replace
# 385                   NaN               screen
# 386                   NaN             cylinder
# 387                   NaN               failed
# 388                   NaN              locking
# 389                   NaN     locking cylinder
# 390                   NaN                 mast
# 391                   NaN              replace
# 392                   NaN            driveline
# 393                   NaN               failed
# 394                   NaN                   on
# 395                   NaN                 rear
# 396                   NaN              replace
# 397                   NaN               failed
# 398                   NaN                   on
# 399                   NaN              replace
# 400                   NaN              between
# 401                   NaN           compressor
# 402                   NaN                 hose
# 403                   NaN             oil tank
# 404                   NaN                 tank
# 405                   NaN           cable tray
# 406                   NaN             catching
# 407                   NaN                 hose
# 408                   NaN                   on
# 409                   NaN                 hose
# 410                   NaN              replace
# 411                   NaN               access
# 412                   NaN                 hose
# 413                   NaN                 leak
# 414                   NaN             pump box
# 415                   NaN                    @
# 416                   NaN             auxilary
# 417                   NaN                 hose
# 418                   NaN              leaking
# 419                   NaN                 pump
# 420                   NaN               before
# 421                   NaN                 hose
# 422                   NaN              leaking
# 423                   NaN                 pump
# 424                   NaN                water
# 425                   NaN         water [ pump
# 426                   NaN              cluster
# 427                   NaN                 hose
# 428                   NaN                   in
# 429                   NaN          in front of
# 430                   NaN              leaking
# 431                   NaN                 mast
# 432                   NaN                 hose
# 433                   NaN              leaking
# 434                   NaN                under
# 435                   NaN              walkway
# 436                   NaN             air tank
# 437                   NaN                 bent
# 438                   NaN                 hose
# 439                   NaN                  off
# 440                   NaN              off the
# 441                   NaN                crane
# 442                   NaN                 hose
# 443                   NaN              lifting
# 444                   NaN        lifting crane
# 445                   NaN                   on
# 446                   NaN                  u/s
# 447                   NaN                   at
# 448                   NaN                 head
# 449                   NaN                 leak
# 450                   NaN               motors
# 451                   NaN          accumulator
# 452                   NaN                   at
# 453                   NaN              at rear
# 454                   NaN                 leak
# 455                   NaN     rear accumulator
# 456                   NaN              at rear
# 457                   NaN                 leak
# 458                   NaN                 pump
# 459                   NaN             rotation
# 460                   NaN        rotation pump
# 461                   NaN                   at
# 462                   NaN                 hyd.
# 463                   NaN            hyd. pipe
# 464                   NaN                 leak
# 465                   NaN                 pipe
# 466                   NaN              between
# 467                   NaN                  fan
# 468                   NaN                 leak
# 469                   NaN                 pump
# 470                   NaN                 from
# 471                   NaN            from rear
# 472                   NaN              housing
# 473                   NaN                 leak
# 474                   NaN                 pump
# 475                   NaN                 rear
# 476                   NaN         rear housing
# 477                   NaN                   in
# 478                   NaN                 leak
# 479                   NaN             in l/h/s
# 480                   NaN                 leak
# 481                   NaN                   in
# 482                   NaN                 leak
# 483                   NaN                 pipe
# 484                   NaN            fuel tank
# 485                   NaN          jumper hose
# 486                   NaN                 leak
# 487                   NaN     leak jumper hose
# 488                   NaN                 main
# 489                   NaN                  r/h
# 490                   NaN                  die
# 491                   NaN          die holders
# 492                   NaN              holders
# 493                   NaN              replace
# 494                   NaN                 dies
# 495                   NaN              replace
# 496                   NaN                 dies
# 497                   NaN              replace
# 498                   NaN                 dies
# 499                   NaN              replace
# 500                   NaN                 dies
# 501                   NaN                   in
# 502                   NaN              replace
# 503                   NaN               wrench
# 504                   NaN                 dies
# 505                   NaN                   on
# 506                   NaN              replace
# 507                   NaN                 dies
# 508                   NaN                   on
# 509                   NaN              replace
# 510                   NaN                 dies
# 511                   NaN                   on
# 512                   NaN              replace
# 513                   NaN                 dies
# 514                   NaN                   on
# 515                   NaN              replace
# 516                   NaN               wrench
# 517                   NaN              replace
# 518                   NaN          flood light
# 519                   NaN   flood light supply
# 520                   NaN             repaired
# 521                   NaN                 head
# 522                   NaN           head slide
# 523                   NaN             repaired
# 524                   NaN                slide
# 525                   NaN       hydraulic pipe
# 526                   NaN                   on
# 527                   NaN             repaired
# 528                   NaN                 leak
# 529                   NaN                   on
# 530                   NaN             repaired
# 531                   NaN          rod support
# 532                   NaN                light
# 533                   NaN             repaired
# 534                   NaN                 leak
# 535                   NaN                   on
# 536                   NaN             repaired
# 537                   NaN                   in
# 538                   NaN             repaired
# 539                   NaN                 seal
# 540                   NaN               window
# 541                   NaN             repaired
# 542                   NaN               wiring
# 543                   NaN             repaired
# 544                   NaN                  box
# 545                   NaN            drive box
# 546                   NaN                 leak
# 547                   NaN                 pump
# 548                   NaN           pump drive
# 549                   NaN                under
# 550                   NaN                leaks
# 551                   NaN               middle
# 552                   NaN              stacker
# 553                   NaN                upper
# 554                   NaN       upper & middle
# 555                   NaN           inspection
# 556                   NaN                leaks
# 557                   NaN            misc jobs
# 558                   NaN                  oil
# 559                   NaN               weekly
# 560                   NaN                   in
# 561                   NaN                level
# 562                   NaN            level low
# 563                   NaN                  low
# 564                   NaN          rotary head
# 565                   NaN         line wearing
# 566                   NaN                  oil
# 567                   NaN             oil line
# 568                   NaN          re-position
# 569                   NaN              wearing
# 570                   NaN                lines
# 571                   NaN                  oil
# 572                   NaN            oil lines
# 573                   NaN              tangled
# 574                   NaN              gearbox
# 575                   NaN                   in
# 576                   NaN                  low
# 577                   NaN                  oil
# 578                   NaN              oil low
# 579                   NaN          rotary head
# 580                   NaN             gear box
# 581                   NaN                   on
# 582                   NaN                 &air
# 583                   NaN            discharge
# 584                   NaN     discharge gauges
# 585                   NaN               gauges
# 586                   NaN                  oil
# 587                   NaN       pressure gauge
