# %%
from annotator import Annotator
from personal_label import Label_Metrics
import graphs as gr

annotator1 = Annotator('annotator1', "annotations-TBikaun.json")
annotator2 = Annotator('annotator2', "annotations-ziyu.zhao.json")
annotator3 = Annotator('annotator3', "annotations-danielsantosa.json")
annotator4 = Annotator('annotator4', "annotations-mhodki.json")
annotator5 = Annotator('annotator5', "annotations-mstewartuwa.json")
annotator6 = Annotator('annotator6', "annotations-caitlinwoods.json")
annotator7 = Annotator('annotator7', "annotations-Tim.json")
label = Label_Metrics(annotator1, annotator2, annotator3)
overall_table = label.get_accumulated_table_labels()

# %%
annotators_agreements = label.get_annotators_labels_agreements(overall_table)
agreement_percentages = label.get_agreement_percentages(annotators_agreements)
agreement_percentages
# Out:
# [{'annotator1': [['NoLabel', 0.8586572438162544],
#    ['Item', 0.8915094339622641],
#    ['Observation/Observed_state Typo', 1.0],
#    ['Observation/Observed_state', 0.9210526315789473],
#    ['Location', 0.8382352941176471],
#    ['Activity', 0.9809523809523809],
#    ['Item Typo', 1.0],
#    ['Observation Observation/Observed_state', 1.0],
#    ['Cardinality', 0.3333333333333333],
#    ['Item Abbreviation', 1.0],
#    ['Consumable', 1.0],
#    ['Attribute', 1.0],
#    ['Observation/Observed_state Abbreviation', 1.0],
#    ['Observation/Qualitative', 1.0],
#    ['Specifier', 0.8571428571428571],
#    ['Location Abbreviation', 1.0],
#    ['Item Unsure', 1.0],
#    ['Typo Item', 1.0],
#    ['Time', 1.0]]},
#  {'annotator2': [['NoLabel', 0.7102473498233216],
#    ['Item', 0.7216981132075472],
#    ['Observation/Observed_state Typo', 0.0],
#    ['Observation/Observed_state', 0.3157894736842105],
#    ['Location', 0.8970588235294118],
#    ['Activity', 0.9428571428571428],
#    ['Item Typo', 0.0],
#    ['Observation Observation/Observed_state', 0.0],
#    ['Cardinality', 1.0],
#    ['Item Abbreviation', 0.25],
#    ['Consumable', 0.8260869565217391],
#    ['Attribute', 0.3333333333333333],
#    ['Observation/Observed_state Abbreviation', 0.0],
#    ['Observation/Qualitative', 0.0],
#    ['Specifier', 0.42857142857142855],
#    ['Location Abbreviation', 0.0],
#    ['Item Unsure', 0.0],
#    ['Typo Item', 0.0],
#    ['Time', 0.0]]},
#  {'annotator3': [['NoLabel', 0.35335689045936397],
#    ['Item', 0.8490566037735849],
#    ['Observation/Observed_state Typo', 0.0],
#    ['Observation/Observed_state', 0.5263157894736842],
#    ['Location', 0.9558823529411765],
#    ['Activity', 0.9619047619047619],
#    ['Item Typo', 0.0],
#    ['Observation Observation/Observed_state', 1.0],
#    ['Cardinality', 1.0],
#    ['Item Abbreviation', 0.0],
#    ['Consumable', 0.043478260869565216],
#    ['Attribute', 0.0],
#    ['Observation/Observed_state Abbreviation', 0.0],
#    ['Observation/Qualitative', 0.5],
#    ['Specifier', 0.38095238095238093],
#    ['Location Abbreviation', 0.0],
#    ['Item Unsure', 0.0],
#    ['Typo Item', 0.0],
#    ['Time', 1.0]]}]

# %%
agreements_summary = label.create_agreement_summary(agreement_percentages)
agreements_summary['annotator2']
# Out:
#                           lowest agreement        medium-low agreement  \
# 0          Observation/Observed_state Typo  Observation/Observed_state
# 1                                Item Typo           Item Abbreviation
# 2   Observation Observation/Observed_state                   Attribute
# 3  Observation/Observed_state Abbreviation                         NaN
# 4                  Observation/Qualitative                         NaN
# 5                    Location Abbreviation                         NaN
# 6                              Item Unsure                         NaN
# 7                                Typo Item                         NaN
# 8                                     Time                         NaN
#
#   medium agreement medium-high agreement high agreement
# 0        Specifier               NoLabel       Location
# 1              NaN                  Item       Activity
# 2              NaN                   NaN    Cardinality
# 3              NaN                   NaN     Consumable
# 4              NaN                   NaN            NaN
# 5              NaN                   NaN            NaN
# 6              NaN                   NaN            NaN
# 7              NaN                   NaN            NaN
# 8              NaN                   NaN            NaN

# %%
gr.create_pie_chart(annotators_agreements)
